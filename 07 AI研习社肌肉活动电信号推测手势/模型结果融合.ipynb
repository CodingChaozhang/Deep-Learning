# %%
# 模型结果融合
import pandas as pd
import numpy as np

df1 = pd.read_csv("./submit5_98.06.csv",names=["id","predict"])
df2 = pd.read_csv("./submit7_98.17.csv",names=["id","predict"])
df3 = pd.read_csv("./submit9_98.23.csv",names=["id","predict"])

df1_predict = df1["predict"]
df2_predict = df2["predict"]
df3_predict = df3["predict"]

df_predict = df1_predict

for i in range(df1.shape[0]):
    if df1_predict[i] != df2_predict[i]:
        df_predict[i] = df3_predict[i]
    else:
        df_predict[i] = df1_predict[i]

id = np.arange(df1.shape[0]) + 1
df = pd.DataFrame({"id":id,"predict":df_predict})
df.to_csv("res.csv",header=None,index=None)

# %%
df4 = pd.read_csv("./submit10_98.csv",names=["id","predict"])
df = pd.read_csv("./submit5_98.06.csv",names=["id","predict"])

df4_predict = df4["predict"]
df_predict = df["predict"]

len = 0 
for i in range(df.shape[0]):
    if df4_predict[i] != df_predict[i]:
        print(i,df4_predict[i],df_predict[i])
        len += 1
print(len)
# Out:
# 5 3 2
# 139 2 3
# 173 3 2
# 189 3 1
# 190 3 1
# 220 3 2
# 284 1 2
# 444 2 0
# 466 1 2
# 541 3 2
# 546 3 1
# 624 2 3
# 724 3 0
# 743 2 3
# 824 2 3
# 926 1 3
# 948 3 2
# 980 2 3
# 984 0 3
# 994 0 3
# 999 3 1
# 1015 3 2
# 1049 1 2
# 1070 2 3
# 1106 2 0
# 1127 2 0
# 1201 2 3
# 1318 0 2
# 1340 3 2
# 1424 3 1
# 1490 3 2
# 1510 3 2
# 1538 2 3
# 1615 3 2
# 1644 1 3
# 1691 1 3
# 1729 3 1
# 1737 1 2
# 1805 3 2
# 1954 1 2
# 1975 1 2
# 1987 2 3
# 2057 3 2
# 2058 0 2
# 2074 1 3
# 2141 3 2
# 2446 3 2
# 2528 1 3
# 2539 1 3
# 2560 2 3
# 2745 1 2
# 2762 1 3
# 2774 2 3
# 2855 3 0
# 2898 3 2
# 2919 2 1
# 2927 3 1
# 2947 3 2
# 2961 0 2
# 3213 1 3
# 3248 1 3
# 3393 3 2
# 3463 2 1
# 63

# %%
df4 = pd.read_csv("./submit27_96.3.csv",names=["id","predict"])
df = pd.read_csv("./submit26_96.07.csv",names=["id","predict"])

df4_predict = df4["predict"]
df_predict = df["predict"]

len = 0 
for i in range(df.shape[0]):
    if df4_predict[i] != df_predict[i]:
        print(i,df4_predict[i],df_predict[i])
        len += 1
print(len)
# Out:
# 101 0.0 1.0
# 106 0.0 1.0
# 143 0.0 1.0
# 237 1.0 0.0
# 285 0.0 1.0
# 391 0.0 1.0
# 422 0.0 1.0
# 459 0.0 1.0
# 493 0.0 1.0
# 511 0.0 1.0
# 524 0.0 1.0
# 696 1.0 0.0
# 768 0.0 1.0
# 792 0.0 1.0
# 800 1.0 0.0
# 820 0.0 1.0
# 977 1.0 0.0
# 1000 1.0 0.0
# 1032 0.0 1.0
# 1091 1.0 0.0
# 1108 1.0 0.0
# 1155 0.0 1.0
# 1172 0.0 1.0
# 1217 0.0 1.0
# 1262 1.0 0.0
# 1323 0.0 1.0
# 1390 1.0 0.0
# 1405 0.0 1.0
# 1469 0.0 1.0
# 1474 0.0 1.0
# 1495 0.0 1.0
# 1510 0.0 1.0
# 1561 0.0 1.0
# 1595 1.0 0.0
# 1604 0.0 1.0
# 1659 0.0 1.0
# 1676 0.0 1.0
# 1713 0.0 1.0
# 1724 0.0 1.0
# 1731 0.0 1.0
# 40
