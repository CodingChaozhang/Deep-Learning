# %%
# 模型结果融合
import pandas as pd
import numpy as np

df1 = pd.read_csv("./submit9_96.5733.csv",names=["id","predict"])
df2 = pd.read_csv("./submit8_96.5667.csv",names=["id","predict"])
df3 = pd.read_csv("./submit6_96.5.csv",names=["id","predict"])

df1_predict = df1["predict"]
df2_predict = df2["predict"]
df3_predict = df3["predict"]

df_predict = df1_predict

for i in range(df1.shape[0]):
    if df1_predict[i] != df2_predict[i]:
        df_predict[i] = df3_predict[i]
    else:
        df_predict[i] = df1_predict[i]

id = np.arange(df1.shape[0]) + 1
df = pd.DataFrame({"id":id,"predict":df_predict})
df.to_csv("res.csv",header=None,index=None)

# %%
import pandas as pd
import numpy as np
df4 = pd.read_csv("./submit9.csv",names=["id","predict"])
df = pd.read_csv("./res.csv",names=["id","predict"])

df4_predict = df4["predict"]
df_predict = df["predict"]

len = 0 
for i in range(df.shape[0]):
    if df4_predict[i] != df_predict[i]:
        print(i,df4_predict[i],df_predict[i])
        len += 1
print(len)
# Out:
# 2 7 6
# 12 5 6
# 14 5 6
# 16 8 6
# 17 7 5
# 20 5 6
# 25 5 6
# 26 5 6
# 27 4 5
# 29 6 5
# 51 7 6
# 69 3 6
# 79 4 5
# 80 3 5
# 89 6 5
# 95 5 6
# 102 6 5
# 110 6 5
# 120 6 5
# 124 5 6
# 148 7 6
# 149 7 6
# 163 6 7
# 168 5 6
# 169 6 7
# 170 4 5
# 178 6 5
# 192 7 6
# 194 5 6
# 195 6 5
# 197 4 5
# 200 8 7
# 223 6 7
# 231 6 5
# 235 7 6
# 239 6 7
# 249 8 6
# 258 7 6
# 267 5 6
# 276 5 6
# 279 3 5
# 280 5 6
# 284 6 5
# 291 7 6
# 304 5 6
# 308 6 5
# 313 6 5
# 326 4 5
# 348 7 5
# 350 7 6
# 376 7 6
# 381 6 5
# 389 7 6
# 393 5 6
# 394 7 6
# 404 7 6
# 414 6 5
# 415 6 5
# 417 8 7
# 430 6 5
# 431 7 6
# 446 6 5
# 447 5 6
# 461 5 6
# 465 4 5
# 469 6 5
# 470 6 5
# 479 6 5
# 487 5 6
# 494 5 6
# 496 6 5
# 505 5 6
# 509 7 6
# 510 7 6
# 516 7 6
# 521 6 7
# 533 4 5
# 542 6 5
# 543 9 7
# 544 7 6
# 545 5 6
# 548 6 5
# 549 6 5
# 551 7 6
# 554 7 6
# 555 6 7
# 556 4 6
# 557 4 5
# 565 6 5
# 566 8 6
# 567 7 6
# 580 6 5
# 583 7 6
# 596 5 6
# 598 5 6
# 611 5 6
# 625 7 6
# 627 5 6
# 633 6 7
# 634 4 5
# 635 7 6
# 636 6 5
# 648 6 7
# 653 5 6
# 656 7 6
# 661 5 6
# 679 7 6
# 687 6 5
# 692 6 5
# 703 5 6
# 705 6 5
# 710 7 6
# 715 6 5
# 720 5 6
# 729 8 6
# 735 6 5
# 741 6 5
# 744 7 6
# 746 7 6
# 761 6 5
# 765 6 5
# 770 5 6
# 776 6 5
# 785 4 6
# 792 7 6
# 794 6 5
# 799 5 6
# 807 6 7
# 813 7 6
# 834 5 6
# 837 7 6
# 855 5 6
# 856 6 5
# 860 6 5
# 866 4 6
# 868 6 5
# 873 5 6
# 879 6 5
# 880 6 7
# 883 6 5
# 891 6 7
# 912 5 6
# 915 5 6
# 922 4 5
# 927 7 8
# 934 5 6
# 937 6 5
# 949 4 5
# 950 7 6
# 958 6 7
# 961 8 6
# 967 6 7
# 978 5 6
# 992 5 6
# 993 7 6
# 996 6 7
# 998 7 6
# 1003 4 5
# 1034 7 6
# 1035 7 6
# 1040 7 6
# 1042 5 6
# 1049 5 6
# 1063 6 5
# 1070 8 7
# 1103 8 7
# 1122 6 7
# 1126 7 6
# 1129 5 6
# 1130 6 5
# 1131 7 6
# 1138 7 6
# 1140 6 5
# 1145 6 5
# 1146 6 5
# 1171 6 5
# 1174 5 6
# 1175 7 6
# 1183 5 6
# 1188 6 7
# 1210 6 5
# 1217 4 6
# 1224 7 6
# 1228 7 6
# 1230 7 6
# 1234 6 5
# 1238 3 6
# 1241 7 6
# 1244 8 7
# 1250 4 5
# 1251 8 6
# 1258 7 6
# 1265 4 5
# 1270 8 6
# 1275 6 5
# 1278 7 6
# 1283 6 5
# 1287 7 6
# 1290 5 6
# 1291 6 5
# 1292 5 6
# 1341 7 8
# 1382 6 5
# 1384 7 6
# 1395 7 6
# 1404 7 6
# 1406 5 6
# 1410 5 6
# 1439 6 5
# 1441 4 5
# 1459 5 6
# 1461 7 6
# 1467 7 6
# 1469 5 6
# 1481 7 6
# 1489 7 6
# 1491 7 6
# 1494 4 6
# 1496 5 6
# 219

# %%
df4 = pd.read_csv("./submit27_96.3.csv",names=["id","predict"])
df = pd.read_csv("./submit26_96.07.csv",names=["id","predict"])

df4_predict = df4["predict"]
df_predict = df["predict"]

len = 0 
for i in range(df.shape[0]):
    if df4_predict[i] != df_predict[i]:
        print(i,df4_predict[i],df_predict[i])
        len += 1
print(len)
# Out:
# 101 0.0 1.0
# 106 0.0 1.0
# 143 0.0 1.0
# 237 1.0 0.0
# 285 0.0 1.0
# 391 0.0 1.0
# 422 0.0 1.0
# 459 0.0 1.0
# 493 0.0 1.0
# 511 0.0 1.0
# 524 0.0 1.0
# 696 1.0 0.0
# 768 0.0 1.0
# 792 0.0 1.0
# 800 1.0 0.0
# 820 0.0 1.0
# 977 1.0 0.0
# 1000 1.0 0.0
# 1032 0.0 1.0
# 1091 1.0 0.0
# 1108 1.0 0.0
# 1155 0.0 1.0
# 1172 0.0 1.0
# 1217 0.0 1.0
# 1262 1.0 0.0
# 1323 0.0 1.0
# 1390 1.0 0.0
# 1405 0.0 1.0
# 1469 0.0 1.0
# 1474 0.0 1.0
# 1495 0.0 1.0
# 1510 0.0 1.0
# 1561 0.0 1.0
# 1595 1.0 0.0
# 1604 0.0 1.0
# 1659 0.0 1.0
# 1676 0.0 1.0
# 1713 0.0 1.0
# 1724 0.0 1.0
# 1731 0.0 1.0
# 40
